# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Kì_1_Năm_3/DS200/DL-LAB3/2_GRU/')
# %run /content/drive/MyDrive/Kì_1_Năm_3/DS200/DL-LAB3/2_GRU/train_gru.py
# Out:
# 2025-11-27 13:32:22,025 - INFO - ==================================================
# 2025-11-27 13:32:22,032 - INFO - Starting training script...
# 2025-11-27 13:32:22,035 - INFO - Device: cuda
# 2025-11-27 13:32:22,036 - INFO - Loading vocab...
# 2025-11-27 13:32:25,719 - INFO - Creating dataset...
# 2025-11-27 13:32:26,271 - INFO - Creating dataloaders...
# 2025-11-27 13:32:26,273 - INFO - Initializing model...
# 2025-11-27 13:32:26,693 - INFO - No checkpoint found. Starting training from scratch...
# 2025-11-27 13:32:26,694 - INFO -
# ...
# 2025-11-27 13:32:26,696 - INFO - Starting Epoch 1
# 2025-11-27 13:32:26,698 - INFO - ==================================================
# Epoch 1 - Training: 100%|██████████| 358/358 [00:04<00:00, 72.21it/s, loss=0.75]
# 2025-11-27 13:32:31,685 - INFO - Epoch 1 - Training Loss: 0.7500 | F1: 0.3177
# Epoch 1 - Evaluating: 100%|██████████| 50/50 [00:00<00:00, 290.53it/s]
# ...
