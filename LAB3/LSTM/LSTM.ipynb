# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Kì_1_Năm_3/DS200/DL-LAB3/1_LSTM')
# %run /content/drive/MyDrive/Kì_1_Năm_3/DS200/DL-LAB3/1_LSTM/train_lstm.py
# Out:
# 2025-11-27 13:21:27,475 - INFO - ==================================================
# 2025-11-27 13:21:27,476 - INFO - Starting training script...
# 2025-11-27 13:21:27,478 - INFO - Device: cuda
# 2025-11-27 13:21:27,480 - INFO - Loading vocab...
# 2025-11-27 13:21:27,733 - INFO - Creating dataset...
# 2025-11-27 13:21:28,246 - INFO - Creating dataloaders...
# 2025-11-27 13:21:28,248 - INFO - Initializing model...
# 2025-11-27 13:21:28,281 - INFO - No checkpoint found. Starting training from scratch...
# 2025-11-27 13:21:28,282 - INFO -
# ...
# 2025-11-27 13:21:28,284 - INFO - Starting Epoch 1
# 2025-11-27 13:21:28,286 - INFO - ==================================================
# Epoch 1 - Training: 100%|██████████| 358/358 [00:05<00:00, 62.82it/s, loss=0.717]
# 2025-11-27 13:21:34,021 - INFO - Epoch 1 - Training Loss: 0.7170 | F1: 0.3396
# Epoch 1 - Evaluating: 100%|██████████| 50/50 [00:00<00:00, 210.35it/s]
# ...
