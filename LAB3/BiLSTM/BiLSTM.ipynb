# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/Kì_1_Năm_3/DS200/DL-LAB3/3_BiLSTM/train_bilstm.py')
# %run /content/drive/MyDrive/Kì_1_Năm_3/DS200/DL-LAB3/3_BiLSTM/train_bilstm.py
# Out:
# 2025-11-27 12:48:26,052 - INFO - ==================================================
# 2025-11-27 12:48:26,057 - INFO - Starting training script...
# 2025-11-27 12:48:26,057 - INFO - Device: cuda
# 2025-11-27 12:48:26,059 - INFO - Loading vocab...
# 2025-11-27 12:48:26,299 - INFO - Creating dataset...
# 2025-11-27 12:48:26,938 - INFO - Creating dataloaders...
# 2025-11-27 12:48:26,940 - INFO - Initializing model...
# 2025-11-27 12:48:27,162 - INFO - No checkpoint found. Starting training from scratch...
# 2025-11-27 12:48:27,163 - INFO -
# ...
# 2025-11-27 12:48:27,165 - INFO - Starting Epoch 1
# 2025-11-27 12:48:27,167 - INFO - ==================================================
# Epoch 1 - Training: 100%|██████████| 158/158 [00:06<00:00, 24.43it/s, loss=0.807]
# 2025-11-27 12:48:33,790 - INFO - Epoch 1 - Training Loss: 0.8066 | F1: 0.1297
# Epoch 1 - Evaluating: 100%|██████████| 63/63 [00:00<00:00, 78.15it/s]
# ...
